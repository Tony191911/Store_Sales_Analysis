# %%
# BASE
# ------------------------------------------------------
import numpy as np
import pandas as pd
import os
import gc
import warnings

# DATA VISUALIZATION
# ------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px


# CONFIGURATIONS
# ------------------------------------------------------
pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:.2f}'.format
warnings.filterwarnings('ignore')

# %%
holidays = pd.read_csv("C://Users//fento//store-sales-time-series-forecasting//holidays_events.csv")
holidays["date"] = pd.to_datetime(holidays.date)

# %%
# Transferred Holidays
tr1 = holidays[(holidays.type == "Holiday") & (holidays.transferred == True)].drop("transferred", axis = 1).reset_index(drop = True)
tr2 = holidays[(holidays.type == "Transfer")].drop("transferred", axis = 1).reset_index(drop = True)
tr = pd.concat([tr1,tr2], axis = 1)
tr = tr.iloc[:, [5,1,2,3,4]]

holidays = holidays[(holidays.transferred == False) & (holidays.type != "Transfer")].drop("transferred", axis = 1)
holidays = holidays.append(tr).reset_index(drop = True)


# Additional Holidays
holidays["description"] = holidays["description"].str.replace("-", "").str.replace("+", "").str.replace('\d+', '')
holidays["type"] = np.where(holidays["type"] == "Additional", "Holiday", holidays["type"])


# Bridge Holidays
holidays["description"] = holidays["description"].str.replace("Puente ", "")
holidays["type"] = np.where(holidays["type"] == "Bridge", "Holiday", holidays["type"])

holidays
# Out:
#           date     type    locale locale_name                    description
# 0   2012-03-02  Holiday     Local       Manta             Fundacion de Manta
# 1   2012-04-01  Holiday  Regional    Cotopaxi  Provincializacion de Cotopaxi
# 2   2012-04-12  Holiday     Local      Cuenca            Fundacion de Cuenca
# 3   2012-04-14  Holiday     Local    Libertad      Cantonizacion de Libertad
# 4   2012-04-21  Holiday     Local    Riobamba      Cantonizacion de Riobamba
# ..         ...      ...       ...         ...                            ...
# 333 2017-04-13  Holiday     Local      Cuenca            Fundacion de Cuenca
# 334 2017-05-26  Holiday  National     Ecuador           Batalla de Pichincha
# 335 2017-08-11  Holiday  National     Ecuador  Primer Grito de Independencia
# 336 2017-09-29  Holiday     Local      Ibarra            Fundacion de Ibarra
# 337 2017-12-08  Holiday     Local       Quito             Fundacion de Quito
#
# [338 rows x 5 columns]

# %%
# Work Day Holidays, that is meant to payback the Bridge.
work_day = holidays[holidays.type == "Work Day"]  
holidays = holidays[holidays.type != "Work Day"]

# %%
event = holidays[holidays.type == "Event"]

# %%
holidays2 = holidays[holidays.type != "Event"]
national = holidays2[(holidays2.locale != "Regional") & (holidays2.locale != "Local")].drop_duplicates()
local = holidays2[holidays2.locale == "Local"].rename({"description":"holiday_local", "locale_name":"city"}, axis = 1).drop("locale", axis = 1).drop_duplicates().drop("type", axis = 1)
regional = holidays2[holidays2.locale == "Regional"].rename({"locale_name":"state", "description":"holiday_regional"}, axis = 1).drop("locale", axis = 1).drop_duplicates().drop("type", axis = 1)

# %%
national[(national['date'] >= '2013-06-01') & (national['date'] <= '2016-11-30')].sort_values(by='date')
# Out:
#           date     type    locale locale_name                    description
# 65  2013-08-10  Holiday  National     Ecuador  Primer Grito de Independencia
# 327 2013-10-11  Holiday  National     Ecuador     Independencia de Guayaquil
# 70  2013-11-02  Holiday  National     Ecuador                Dia de Difuntos
# 71  2013-11-03  Holiday  National     Ecuador        Independencia de Cuenca
# 80  2013-12-21  Holiday  National     Ecuador                        Navidad
# 81  2013-12-22  Holiday  National     Ecuador                        Navidad
# 83  2013-12-23  Holiday  National     Ecuador                        Navidad
# 84  2013-12-24  Holiday  National     Ecuador                        Navidad
# 85  2013-12-25  Holiday  National     Ecuador                        Navidad
# 86  2013-12-26  Holiday  National     Ecuador                        Navidad
# 87  2013-12-31  Holiday  National     Ecuador             Primer dia del ano
# 88  2014-01-01  Holiday  National     Ecuador             Primer dia del ano
# 90  2014-03-03  Holiday  National     Ecuador                       Carnaval
# 91  2014-03-04  Holiday  National     Ecuador                       Carnaval
# 95  2014-04-18  Holiday  National     Ecuador                  Viernes Santo
# 97  2014-05-01  Holiday  National     Ecuador                Dia del Trabajo
# 98  2014-05-10  Holiday  National     Ecuador                Dia de la Madre
# 101 2014-05-24  Holiday  National     Ecuador           Batalla de Pichincha
# 126 2014-08-10  Holiday  National     Ecuador  Primer Grito de Independencia
# 328 2014-10-10  Holiday  National     Ecuador     Independencia de Guayaquil
# 131 2014-11-02  Holiday  National     Ecuador                Dia de Difuntos
# 132 2014-11-03  Holiday  National     Ecuador        Independencia de Cuenca
# 144 2014-12-21  Holiday  National     Ecuador                        Navidad
# 146 2014-12-22  Holiday  National     Ecuador                        Navidad
# 147 2014-12-23  Holiday  National     Ecuador                        Navidad
# 148 2014-12-24  Holiday  National     Ecuador                        Navidad
# 149 2014-12-25  Holiday  National     Ecuador                        Navidad
# 150 2014-12-26  Holiday  National     Ecuador                        Navidad
# 152 2014-12-31  Holiday  National     Ecuador             Primer dia del ano
# 153 2015-01-01  Holiday  National     Ecuador             Primer dia del ano
# 154 2015-01-02  Holiday  National     Ecuador             Primer dia del ano
# 156 2015-02-16  Holiday  National     Ecuador                       Carnaval
# 157 2015-02-17  Holiday  National     Ecuador                       Carnaval
# 160 2015-04-03  Holiday  National     Ecuador                  Viernes Santo
# 164 2015-05-01  Holiday  National     Ecuador                Dia del Trabajo
# 165 2015-05-09  Holiday  National     Ecuador                Dia de la Madre
# 168 2015-05-24  Holiday  National     Ecuador           Batalla de Pichincha
# 179 2015-08-10  Holiday  National     Ecuador  Primer Grito de Independencia
# 184 2015-10-09  Holiday  National     Ecuador     Independencia de Guayaquil
# 185 2015-11-02  Holiday  National     Ecuador                Dia de Difuntos
# 186 2015-11-03  Holiday  National     Ecuador        Independencia de Cuenca
# 197 2015-12-21  Holiday  National     Ecuador                        Navidad
# 198 2015-12-22  Holiday  National     Ecuador                        Navidad
# 200 2015-12-23  Holiday  National     Ecuador                        Navidad
# 201 2015-12-24  Holiday  National     Ecuador                        Navidad
# 202 2015-12-25  Holiday  National     Ecuador                        Navidad
# 203 2015-12-26  Holiday  National     Ecuador                        Navidad
# 204 2015-12-31  Holiday  National     Ecuador             Primer dia del ano
# 205 2016-01-01  Holiday  National     Ecuador             Primer dia del ano
# 206 2016-02-08  Holiday  National     Ecuador                       Carnaval
# 207 2016-02-09  Holiday  National     Ecuador                       Carnaval
# 209 2016-03-25  Holiday  National     Ecuador                  Viernes Santo
# 229 2016-05-01  Holiday  National     Ecuador                Dia del Trabajo
# 236 2016-05-07  Holiday  National     Ecuador                Dia de la Madre
# 329 2016-05-27  Holiday  National     Ecuador           Batalla de Pichincha
# 331 2016-08-12  Holiday  National     Ecuador  Primer Grito de Independencia
# 262 2016-10-09  Holiday  National     Ecuador     Independencia de Guayaquil
# 263 2016-11-02  Holiday  National     Ecuador                Dia de Difuntos
# 264 2016-11-03  Holiday  National     Ecuador        Independencia de Cuenca
# 265 2016-11-04  Holiday  National     Ecuador                Dia de Difuntos

# %%
combined = pd.concat([work_day, event, national], ignore_index=True).sort_values(by='date')
combined = combined.reset_index(drop=True)
combined
# Out:
#           date     type    locale locale_name                    description
# 0   2012-08-10  Holiday  National     Ecuador  Primer Grito de Independencia
# 1   2012-10-12  Holiday  National     Ecuador     Independencia de Guayaquil
# 2   2012-11-02  Holiday  National     Ecuador                Dia de Difuntos
# 3   2012-11-03  Holiday  National     Ecuador        Independencia de Cuenca
# 4   2012-12-21  Holiday  National     Ecuador                        Navidad
# ..         ...      ...       ...         ...                            ...
# 158 2017-12-22  Holiday  National     Ecuador                        Navidad
# 159 2017-12-23  Holiday  National     Ecuador                        Navidad
# 160 2017-12-24  Holiday  National     Ecuador                        Navidad
# 161 2017-12-25  Holiday  National     Ecuador                        Navidad
# 162 2017-12-26  Holiday  National     Ecuador                        Navidad
#
# [163 rows x 5 columns]

# %%
combined['date'].duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 158    False
# 159    False
# 160    False
# 161    False
# 162    False
# Name: date, Length: 163, dtype: bool

# %%
combined.to_csv('C://Users//fento//store-sales-time-series-forecasting//national.csv', index=False)
local.to_csv('C://Users//fento//store-sales-time-series-forecasting//local.csv', index=False)
regional.to_csv('C://Users//fento//store-sales-time-series-forecasting//regional.csv', index=False)
